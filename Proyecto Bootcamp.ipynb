# %% [markdown]
# *PROYECTO BOOTCAMP*
#
# **DIEGO SIERRA**

# %% [raw]
# #### IMPORTACION DE LA INFORMACION
#
# CODIGO

# %%
import pandas as pd

# %%
comics=pd.read_csv('comics_data.csv')
comics
# Out:
#         Unnamed: 0                 title  \
# 0                0           'Mazing Man
# 1                1           'Mazing Man
# 2                2           'Mazing Man
# 3                3           'Mazing Man
# 4                4           'Mazing Man
# ...            ...                   ...
# 461296      461296       Sammy the Mouse
# 461297      461297         Sky In Stereo
# 461298      461298      Skyway Sleepless
# 461299      461299  South Beloit Journal
# 461300      461300    Super Magic Forest
#
#                                                title_link  \
# 0                     /series/4036/0/dc-comics-mazing-man
# 1                     /series/4036/0/dc-comics-mazing-man
# 2                     /series/4036/0/dc-comics-mazing-man
# 3                     /series/4036/0/dc-comics-mazing-man
# 4                     /series/4036/0/dc-comics-mazing-man
# ...                                                   ...
# ...

# %% [markdown]
# ** Conociendo tus datos
# 1. Definicion del problema
# 2. Metadatos
# 3. Carga de Datos
# 4. Datos Ordenados
# 5. formatos y codificaciones
# 6. tipos de datos
#
# conjunto de datos:
#
#
# título
# título_enlace
# problema_enlace
# portada_enlace
# asunto
# fecha_de_portada
# precio_de_cobertura
# valor actual
# enlace histórico de precios...
# nombres_de_los_contribuyentes
# contribuidores_roles
# caracteres
# pub_id
# años de volumen
# problemas _ totales
# pub_nombre
# pub_titles_total
# pub_issues_total
#
#
#  0   Unnamed: 0          461301 non-null  int64
#  1   title               461301 non-null  object
#  2   title_link          461301 non-null  object
#  3   issue_link          461301 non-null  object
#  4   cover_link          461301 non-null  object
#  5   issue               461301 non-null  object
#  6   cover_date          369712 non-null  object
#  7   cover_price         461301 non-null  object
#  8   current_value       461301 non-null  object
#  9   hist_prices_link    461301 non-null  object
#  10  searched            461301 non-null  int64
#  11  owned               461301 non-null  int64
#  12  pages               208011 non-null  float64
#  13  rating              461301 non-null  float64
#  14  rating_count        461301 non-null  int64
#  15  ISBN-UPC            197912 non-null  object
#  16  est_print_run       30446 non-null   object
#  17  variant_of          131457 non-null  object
#  18  preview             15563 non-null   object
#  19  synopsis            291190 non-null  object
#  20  contributors_names  461301 non-null  object
#  21  contributors_roles  461301 non-null  object
#  22  characters          461301 non-null  object
#  23  pub_id              461301 non-null  float64
#  24  volume              210548 non-null  object
#  25  years               459453 non-null  object
#  26  issues_total        456401 non-null  float64
#  27  pub_name            461301 non-null  object
#  28  pub_titles_total    461301 non-null  int64
#  29  pub_issues_total    461301 non-null  int64
# dtypes: float64(4), int64(6), object(20)
# memory usage: 105.6+ MB
#
# 0 Sin nombre: 0 461301 int64 no nulo
#  1 título 461301 objeto no nulo
#  2 title_link 461301 objeto no nulo
#  3 problema_enlace 461301 objeto no nulo
#  4 cover_link 461301 objeto no nulo
#  5 problema 461301 objeto no nulo
#  6 cover_date 369712 objeto no nulo
#  7 cover_price 461301 objeto no nulo
#  8 valor_actual 461301 objeto no nulo
#  9 hist_prices_link 461301 objeto no nulo
#  10 búsquedas 461301 int64 no nulo
#  11 propiedad 461301 no nulo int64
#  12 páginas 208011 no nulo float64
#  13 clasificación 461301 flotación no nula64
#  14 rating_count 461301 no nulo int64
#  15 ISBN-UPC 197912 objeto no nulo
#  16 est_print_run 30446 objeto no nulo
#  17 variant_of 131457 objeto no nulo
#  18 vista previa 15563 objeto no nulo
#  19 sinopsis 291190 objeto no nulo
#  20 contribuyentes_names 461301 objeto no nulo
#  21 contribuidores_roles 461301 objeto no nulo
#  22 caracteres 461301 objeto no nulo
#  23 pub_id 461301 no nulo float64
#  24 volumen 210548 objeto no nulo
#  25 años 459453 objeto no nulo
#  26 problemas_total 456401 flotante no nulo64
#  27 pub_name 461301 objeto no nulo
#  28 pub_titles_total 461301 no nulo int64
#  29 pub_issues_total 461301 int64 no nulo

# %%
comics.head(50) #traer las50primeras columnas
# Out:
#     Unnamed: 0                                             title  \
# 0            0                                       'Mazing Man
# 1            1                                       'Mazing Man
# 2            2                                       'Mazing Man
# 3            3                                       'Mazing Man
# 4            4                                       'Mazing Man
# 5            5                                       'Mazing Man
# 6            6                                       'Mazing Man
# 7            7                                       'Mazing Man
# 8            8                                       'Mazing Man
# 9            9                                       'Mazing Man
# 10          10                                       'Mazing Man
# 11          11                                       'Mazing Man
# 12          12  'Til Death Do Us Part: To Love, Honor and Perish
# ...

# %%
comics.tail(10) #selecciona las ultimas filas
# Out:
#         Unnamed: 0                         title  \
# 461291      461291                One Dirty Tree
# 461292      461292                 Over the Wall
# 461293      461293                 Plans We Made
# 461294      461294  Rules for Dating My Daughter
# 461295      461295               Sammy the Mouse
# 461296      461296               Sammy the Mouse
# 461297      461297                 Sky In Stereo
# 461298      461298              Skyway Sleepless
# 461299      461299          South Beloit Journal
# 461300      461300            Super Magic Forest
#
#                                                title_link  \
# 461291   /series/55191/0/uncivilized-books-one-dirty-tree
# 461292    /series/33983/0/uncivilized-books-over-the-wall
# 461293    /series/40769/0/uncivilized-books-plans-we-made
# 461294  /series/43084/0/uncivilized-books-rules-for-da...
# 461295  /series/33926/0/uncivilized-books-sammy-the-mouse
# 461296  /series/33926/0/uncivilized-books-sammy-the-mouse
# ...

# %%
comics['title'] #traer la informaicon de una columna
# Out:
# 0                  'Mazing Man
# 1                  'Mazing Man
# 2                  'Mazing Man
# 3                  'Mazing Man
# 4                  'Mazing Man
#                   ...
# 461296         Sammy the Mouse
# 461297           Sky In Stereo
# 461298        Skyway Sleepless
# 461299    South Beloit Journal
# 461300      Super Magic Forest
# Name: title, Length: 461301, dtype: object

# %%
comics['cover_link']
# Out:
# 0         /cover-scan/acb40c8a57d50781194e37be2a94b3d5/l...
# 1         /cover-scan/293f4e231eccb71ad6e6bc3fe3e49c4f/l...
# 2         /cover-scan/45c7a284efa7d07f7bb5c9afb3080ffd/l...
# 3         /cover-scan/21764f5da802b25622831976f1619aa4/l...
# 4         /cover-scan/3a4df503a1fb2450b1227f4c1f0c45d9/l...
#                                 ...
# 461296    /cover-scan/0c2d5e336808e5526b775e701070d220/x...
# 461297    /cover-scan/bb62e7dc9ba7373068a4ddce63c50a21/x...
# 461298    /cover-scan/7635babad3c9a05fd7c5feff88b2250f/x...
# 461299    /cover-scan/234c46b0df9ea1e4b59d4cefe2a18ba5/x...
# 461300    /cover-scan/164853aacc3de6138e2c6b01f1d44e10/x...
# Name: cover_link, Length: 461301, dtype: object

# %%
comics.title   #traer la informacion de una columna por los atributos
# Out:
# 0                  'Mazing Man
# 1                  'Mazing Man
# 2                  'Mazing Man
# 3                  'Mazing Man
# 4                  'Mazing Man
#                   ...
# 461296         Sammy the Mouse
# 461297           Sky In Stereo
# 461298        Skyway Sleepless
# 461299    South Beloit Journal
# 461300      Super Magic Forest
# Name: title, Length: 461301, dtype: object

# %%
comics.iloc[4] # traer elementos filas a partir de un index
# Out:
# Unnamed: 0                                                            4
# title                                                       'Mazing Man
# title_link                          /series/4036/0/dc-comics-mazing-man
# issue_link            https://comicbookrealm.com/series/4036/54342/d...
# cover_link            /cover-scan/3a4df503a1fb2450b1227f4c1f0c45d9/l...
# issue                                                               # 2
# cover_date                                                      Feb '86
# cover_price                                                       $0.75
# current_value                                                     $3.00
# hist_prices_link      /comic.php?a=historical&comic=54342?keepThis=t...
# searched                                                            413
# owned                                                               118
# pages                                                               NaN
# ...

# %%
comics.iloc[[4,5,6]]
# Out:
#    Unnamed: 0        title                           title_link  \
# 4           4  'Mazing Man  /series/4036/0/dc-comics-mazing-man
# 5           5  'Mazing Man  /series/4036/0/dc-comics-mazing-man
# 6           6  'Mazing Man  /series/4036/0/dc-comics-mazing-man
#
#                                           issue_link  \
# 4  https://comicbookrealm.com/series/4036/54342/d...
# 5  https://comicbookrealm.com/series/4036/54343/d...
# 6  https://comicbookrealm.com/series/4036/54344/d...
#
#                                           cover_link issue cover_date  \
# 4  /cover-scan/3a4df503a1fb2450b1227f4c1f0c45d9/l...   # 2    Feb '86
# 5  /cover-scan/93e834de5ae9c81bc0e429317ad399c1/l...   # 3    Mar '86
# 6  /cover-scan/8d3c396c1e9f2d8988c9e164f895232d/l...   # 4    Apr '86
#
#   cover_price current_value  \
# 4       $0.75         $3.00
# 5       $0.75         $3.00
# 6       $0.75         $3.00
#
#                                     hist_prices_link  ...  \
# ...

# %%
comics.dropna()
# Out:
#         Unnamed: 0                               title  \
# 369159      369159  Betrayal of the Planet of the Apes
#
#                                                title_link  \
# 369159  /series/29198/0/boom-studios-betrayal-of-the-p...
#
#                                                issue_link  \
# 369159  https://comicbookrealm.com/series/29198/264366...
#
#                                                cover_link issue cover_date  \
# 369159  /cover-scan/f1e925c5b8bd3c45eb212c3df6b19114/x...  # 1b    Nov '11
#
#        cover_price current_value  \
# 369159       $3.99         $4.00
#
#                                          hist_prices_link  ...  \
# 369159  /comic.php?a=historical&comic=264366?keepThis=...  ...
#
#                            contributors_names              contributors_roles  \
# 369159  ['Corinna Bechko', 'Gabriel Hardman']  ['Scripts', 'Scripts-Pencils']
#
#                     characters  pub_id  volume      years issues_total  \
# ...

# %%
comics[comics['pub_name']=='DC Comics']
# Out:
#        Unnamed: 0        title                           title_link  \
# 0               0  'Mazing Man  /series/4036/0/dc-comics-mazing-man
# 1               1  'Mazing Man  /series/4036/0/dc-comics-mazing-man
# 2               2  'Mazing Man  /series/4036/0/dc-comics-mazing-man
# 3               3  'Mazing Man  /series/4036/0/dc-comics-mazing-man
# 4               4  'Mazing Man  /series/4036/0/dc-comics-mazing-man
# ...           ...          ...                                  ...
# 98586       98586     inFamous   /series/27674/0/dc-comics-infamous
# 98587       98587     inFamous   /series/27674/0/dc-comics-infamous
# 98588       98588     inFamous   /series/27674/0/dc-comics-infamous
# 98589       98589     inFamous   /series/27674/0/dc-comics-infamous
# 98590       98590     inFamous   /series/27674/0/dc-comics-infamous
#
#                                               issue_link  \
# 0      https://comicbookrealm.com/series/4036/54341/d...
# ...

# %%
comics[comics['years'] < '1980' ]
# Out:
#         Unnamed: 0                     title  \
# 15              15         1st Issue Special
# 16              16         1st Issue Special
# 17              17         1st Issue Special
# 18              18         1st Issue Special
# 19              19         1st Issue Special
# ...            ...                       ...
# 461109      461109  Tarou: Fils De La Jungle
# 461110      461110  Tarou: Fils De La Jungle
# 461111      461111  Tarou: Fils De La Jungle
# 461138      461138         Out of this World
# 461139      461139         Out of this World
#
#                                                title_link  \
# 15             /series/2609/0/dc-comics-1st-issue-special
# 16             /series/2609/0/dc-comics-1st-issue-special
# 17             /series/2609/0/dc-comics-1st-issue-special
# 18             /series/2609/0/dc-comics-1st-issue-special
# 19             /series/2609/0/dc-comics-1st-issue-special
# ...                                                   ...
# ...

# %%
comics[(comics['years']>'1988')&(comics['years']<'1990')]
# Out:
#         Unnamed: 0                          title  \
# 1704          1704    Advanced Dungeons & Dragons
# 1705          1705    Advanced Dungeons & Dragons
# 1706          1706    Advanced Dungeons & Dragons
# 1707          1707    Advanced Dungeons & Dragons
# 1708          1708    Advanced Dungeons & Dragons
# ...            ...                            ...
# 455021      455021                 Tuna Casserole
# 455022      455022                 Tuna Casserole
# 455023      455023                 Tuna Casserole
# 455024      455024                 Tuna Casserole
# 455059      455059  The Preservation of Obscurity
#
#                                                title_link  \
# 1704    /series/2622/0/dc-comics-advanced-dungeons-dra...
# 1705    /series/2622/0/dc-comics-advanced-dungeons-dra...
# 1706    /series/2622/0/dc-comics-advanced-dungeons-dra...
# 1707    /series/2622/0/dc-comics-advanced-dungeons-dra...
# 1708    /series/2622/0/dc-comics-advanced-dungeons-dra...
# ...

# %%
comics.query( 'years  > "1988" and years < "1990"')
# Out:
#         Unnamed: 0                          title  \
# 1704          1704    Advanced Dungeons & Dragons
# 1705          1705    Advanced Dungeons & Dragons
# 1706          1706    Advanced Dungeons & Dragons
# 1707          1707    Advanced Dungeons & Dragons
# 1708          1708    Advanced Dungeons & Dragons
# ...            ...                            ...
# 455021      455021                 Tuna Casserole
# 455022      455022                 Tuna Casserole
# 455023      455023                 Tuna Casserole
# 455024      455024                 Tuna Casserole
# 455059      455059  The Preservation of Obscurity
#
#                                                title_link  \
# 1704    /series/2622/0/dc-comics-advanced-dungeons-dra...
# 1705    /series/2622/0/dc-comics-advanced-dungeons-dra...
# 1706    /series/2622/0/dc-comics-advanced-dungeons-dra...
# 1707    /series/2622/0/dc-comics-advanced-dungeons-dra...
# 1708    /series/2622/0/dc-comics-advanced-dungeons-dra...
# ...

# %%
comics[comics['title_link'].str.endswith('a')]
# Out:
#         Unnamed: 0                                    title  \
# 3792          3792                                    Anima
# 3793          3793                                    Anima
# 3794          3794                                    Anima
# 3795          3795                                    Anima
# 3796          3796                                    Anima
# ...            ...                                      ...
# 460810      460810                     Rockstar: Super Diva
# 461124      461124    Vlad the Impaler: Man Who was Dracula
# 461193      461193              On the Run in Ancient China
# 461234      461234  Little White Duck: A Childhood in China
# 461237      461237      Q & Ray: Case 1 - Missing Mola Lisa
#
#                                                title_link  \
# 3792                       /series/2676/0/dc-comics-anima
# 3793                       /series/2676/0/dc-comics-anima
# 3794                       /series/2676/0/dc-comics-anima
# ...

# %%
comics[comics['title'].str.endswith('na')]['title']
# Out:
# 14165                                      Countdown: Arena
# 14166                                      Countdown: Arena
# 14167                                      Countdown: Arena
# 14168                                      Countdown: Arena
# 14169                                      Countdown: Arena
#                                 ...
# 454826                      Cavewoman: Sisters of the Arena
# 454827                      Cavewoman: Sisters of the Arena
# 459850    Graphic Library: Building the Great Wall of China
# 461193                          On the Run in Ancient China
# 461234              Little White Duck: A Childhood in China
# Name: title, Length: 1389, dtype: object

# %%
comics[(comics['years']>'1988')|(comics['years']<'1990')]
# Out:
#         Unnamed: 0                 title  \
# 0                0           'Mazing Man
# 1                1           'Mazing Man
# 2                2           'Mazing Man
# 3                3           'Mazing Man
# 4                4           'Mazing Man
# ...            ...                   ...
# 461296      461296       Sammy the Mouse
# 461297      461297         Sky In Stereo
# 461298      461298      Skyway Sleepless
# 461299      461299  South Beloit Journal
# 461300      461300    Super Magic Forest
#
#                                                title_link  \
# 0                     /series/4036/0/dc-comics-mazing-man
# 1                     /series/4036/0/dc-comics-mazing-man
# 2                     /series/4036/0/dc-comics-mazing-man
# 3                     /series/4036/0/dc-comics-mazing-man
# 4                     /series/4036/0/dc-comics-mazing-man
# ...                                                   ...
# ...

# %%
comics[(comics['years']<'1988')].count()
# Out:
# Unnamed: 0            136831
# title                 136831
# title_link            136831
# issue_link            136831
# cover_link            136831
# issue                 136831
# cover_date            106863
# cover_price           136831
# current_value         136831
# hist_prices_link      136831
# searched              136831
# owned                 136831
# pages                  71897
# rating                136831
# rating_count          136831
# ISBN-UPC               11100
# est_print_run           3145
# variant_of             11465
# preview                  421
# synopsis               46093
# contributors_names    136831
# contributors_roles    136831
# characters            136831
# pub_id                136831
# volume                 63250
# years                 136831
# issues_total          135388
# pub_name              136831
# pub_titles_total      136831
# pub_issues_total      136831
# dtype: int64

# %%
comics[(comics['years']<'1988')]['years'].count()
# Out:
# 136831

# %%
comics.groupby(comics['years'])

# %%
comics.groupby('years').count()
# Out:
#              Unnamed: 0  title  title_link  issue_link  cover_link  issue  \
# years
# 1842                  1      1           1           1           1      1
# 1845                  1      1           1           1           1      1
# 1846                  1      1           1           1           1      1
# 1847                  2      2           2           2           2      2
# 1849                  2      2           2           2           2      2
# ...                 ...    ...         ...         ...         ...    ...
# GN                    1      1           1           1           1      1
# Late 1960's           1      1           1           1           1      1
# No Date               9      9           9           9           9      9
# Undated               1      1           1           1           1      1
# Unknown               3      3           3           3           3      3
#
# ...

# %%
comics.groupby('years').count().index
# Out:
# Index(['1842', '1845', '1846', '1847', '1849', '1868', '1871', '1874', '1877',
#        '1878',
#        ...
#        '2021-2022', '2021-Present', '2022', '2022 - present', '2022-Present',
#        'GN', 'Late 1960's', 'No Date', 'Undated', 'Unknown'],
#       dtype='object', name='years', length=2742)

# %%
comics.groupby('years').count().index.values
# Out:
# array(['1842', '1845', '1846', ..., 'No Date', 'Undated', 'Unknown'],
#       dtype=object)

# %%
comics.groupby('years')['years'].count()
# Out:
# years
# 1842           1
# 1845           1
# 1846           1
# 1847           2
# 1849           2
#               ..
# GN             1
# Late 1960's    1
# No Date        9
# Undated        1
# Unknown        3
# Name: years, Length: 2742, dtype: int64

# %%
comics.value_counts(comics['years'])
# Out:
# years
# 2021         10021
# 2019          6845
# 2017          6389
# 2015          6067
# 2018          5935
#              ...
# 1940s            1
# 2005 2020        1
# 2006 2013        1
# 1986 2012        1
# 1842             1
# Length: 2742, dtype: int64

# %%
comics[(comics['years'] > '1988')].groupby('years')['years'].count()
# Out:
# years
# 1988 - 1987     4
# 1988 - 1989    62
# 1988 - 1990     8
# 1988 - 2021     1
# 1988 1990       1
#                ..
# GN              1
# Late 1960's     1
# No Date         9
# Undated         1
# Unknown         3
# Name: years, Length: 1444, dtype: int64

# %%
comics[(comics['years'] > '1988')].groupby('years')['years'].count().sort_values()
# Out:
# years
# 2006 2013             1
# 2002 - 2021           1
# 2011 2020             1
# 1998 2015 2018        1
# 2007 2008             1
#                   ...
# 2018               5935
# 2015               6067
# 2017               6389
# 2019               6845
# 2021              10021
# Name: years, Length: 1444, dtype: int64

# %%
comics[(comics['years'] > '1988')].groupby('years')['years'].count().sort_values(ascending=False)
# Out:
# years
# 2021              10021
# 2019               6845
# 2017               6389
# 2015               6067
# 2018               5935
#                   ...
# 2007 2008             1
# 1998 2015 2018        1
# 2011 2020             1
# 2002 - 2021           1
# 2006 2013             1
# Name: years, Length: 1444, dtype: int64

# %%
comics[(comics['years'] > '1988')].groupby('years')['years'].count().sort_values(ascending=False).head(1)
# Out:
# years
# 2021    10021
# Name: years, dtype: int64

# %%
comics[(comics['years'] > '1988')].groupby('years')['years'].count().sort_values(ascending=False).head(5)
# Out:
# years
# 2021    10021
# 2019     6845
# 2017     6389
# 2015     6067
# 2018     5935
# Name: years, dtype: int64

# %%
#cambiar valores nulos por predeterminados <<<<<comics.fillna('name': 'sin nombre', 'email':'example@exmple.com')

# %%
comics[(comics['years']>'1988')|(comics['years']<'1990')][['title', 'years']]
# Out:
#                        title      years
# 0                'Mazing Man       1986
# 1                'Mazing Man       1986
# 2                'Mazing Man       1986
# 3                'Mazing Man       1986
# 4                'Mazing Man       1986
# ...                      ...        ...
# 461296       Sammy the Mouse  2011 2013
# 461297         Sky In Stereo       2019
# 461298      Skyway Sleepless       2014
# 461299  South Beloit Journal       2017
# 461300    Super Magic Forest       2021
#
# [459453 rows x 2 columns]

# %%
comics[comics['years'].between('1988','1999')][['title', 'years']]
# Out:
#                title      years
# 204       A. Bizarro       1999
# 205       A. Bizarro       1999
# 206       A. Bizarro       1999
# 207       A. Bizarro       1999
# 1686    Adam Strange       1990
# ...              ...        ...
# 461249        Netman       1992
# 461250     Dr. Weird  1997-1998
# 461251     Dr. Weird  1997-1998
# 461252      Y's Guys       1999
# 461253      Y's Guys       1999
#
# [65111 rows x 2 columns]

# %%
comics[comics['title'].str.startswith('a')]
# Out:
#         Unnamed: 0            title  \
# 232208      232208  a.k.a. Goldfish
# 232209      232209  a.k.a. Goldfish
# 232210      232210  a.k.a. Goldfish
# 232211      232211  a.k.a. Goldfish
# 232212      232212  a.k.a. Goldfish
#
#                                         title_link  \
# 232208  /series/7448/0/caliber-comics-aka-goldfish
# 232209  /series/7448/0/caliber-comics-aka-goldfish
# 232210  /series/7448/0/caliber-comics-aka-goldfish
# 232211  /series/7448/0/caliber-comics-aka-goldfish
# 232212  /series/7448/0/caliber-comics-aka-goldfish
#
#                                                issue_link  \
# 232208  https://comicbookrealm.com/series/7448/91578/c...
# 232209  https://comicbookrealm.com/series/7448/91575/c...
# 232210  https://comicbookrealm.com/series/7448/91579/c...
# 232211  https://comicbookrealm.com/series/7448/91577/c...
# 232212  https://comicbookrealm.com/series/7448/91576/c...
#
# ...

# %%
comics[comics['title'].str.endswith('a')]
# Out:
#         Unnamed: 0                                    title  \
# 3792          3792                                    Anima
# 3793          3793                                    Anima
# 3794          3794                                    Anima
# 3795          3795                                    Anima
# 3796          3796                                    Anima
# ...            ...                                      ...
# 461124      461124    Vlad the Impaler: Man Who was Dracula
# 461193      461193              On the Run in Ancient China
# 461234      461234  Little White Duck: A Childhood in China
# 461237      461237      Q & Ray: Case 1 - Missing Mola Lisa
# 461245      461245                       The Inkberg Enigma
#
#                                                title_link  \
# 3792                       /series/2676/0/dc-comics-anima
# 3793                       /series/2676/0/dc-comics-anima
# 3794                       /series/2676/0/dc-comics-anima
# ...

# %%
comics[comics['title'].str.contains('a')]
# Out:
#         Unnamed: 0                 title  \
# 0                0           'Mazing Man
# 1                1           'Mazing Man
# 2                2           'Mazing Man
# 3                3           'Mazing Man
# 4                4           'Mazing Man
# ...            ...                   ...
# 461295      461295       Sammy the Mouse
# 461296      461296       Sammy the Mouse
# 461298      461298      Skyway Sleepless
# 461299      461299  South Beloit Journal
# 461300      461300    Super Magic Forest
#
#                                                title_link  \
# 0                     /series/4036/0/dc-comics-mazing-man
# 1                     /series/4036/0/dc-comics-mazing-man
# 2                     /series/4036/0/dc-comics-mazing-man
# 3                     /series/4036/0/dc-comics-mazing-man
# 4                     /series/4036/0/dc-comics-mazing-man
# ...                                                   ...
# ...

# %%
comics[comics['cover_date'].isnull()][['title']]
# Out:
#                                       title
# 28                               3-D Batman
# 29                               3-D Batman
# 98                            52: Companion
# 99                               52: Covers
# 234     Absolute Green Arrow by Kevin Smith
# ...                                     ...
# 461276                        Ginseng Roots
# 461288                           My Dog Ivy
# 461293                        Plans We Made
# 461298                     Skyway Sleepless
# 461299                 South Beloit Journal
#
# [91589 rows x 1 columns]

# %%
comics[(comics['years'] > '1988')]['years'].mean()

# %%
comics.info()

# %%
comics.describe() # metricas - estadisticas univariantes

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
datacomics = comics
sns.displot(datacomics, x="pub_titles_total", bins=70)
plt.show()

# %%
datacomics = comics[(comics['pub_titles_total'] > 4000)]
sns.displot(datacomics, x="pub_titles_total", bins=20)
plt.show()

# %%
datacomics = comics[(comics['pub_titles_total'] < 4000)]
sns.displot(datacomics, x="pub_titles_total", bins=20)
plt.show()

# %%
sns.displot(comics, x="pub_titles_total", y="cover_price", hue="current_value" )
plt.show()
